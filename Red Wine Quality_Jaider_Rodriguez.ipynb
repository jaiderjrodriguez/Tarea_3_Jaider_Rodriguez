# %% [markdown]
# Dataset Arboles de Decisión – Red Wine Quality:
#
# 1)	Realizar un análisis exploratorio de los datos para identificar relaciones entre variables, valores atípicos, tendencias, etc.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
data = pd.read_csv("C:/Red Wine Quality/winequality-red.csv")
data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# 2)	Preprocesar los datos limpiándolos, tratando valores faltantes y transformándolos según sea necesario.

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# No existen valores nulos por lo cual no hay necesidad de realizar ninguna mitigación.

# %% [markdown]
# 3)	Seleccionar las características más relevantes para entrenar el modelo utilizando selección de características.
#
# Características de interés
#
# Calidad: Indica la calidad de 6 clases de vino

# %%
data["quality"].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
plt.hist(data.quality)
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# En base al histograma se puede concluir que el dataset posee las características de 6 clases de vino, pero esta no está balanceada.

# %%
sns.scatterplot(x = "alcohol", y = "density", hue = "quality", data = data)
# Out:
# <Axes: xlabel='alcohol', ylabel='density'>

# %% [markdown]
# En base al diagrama de dispersión se puede concluir que entre menor sea la cantidad de alcohol presente en el Vino, mayor será la densidad que este posea,  pero entre mayor sea la cantidad de alcohol mayor será su calidad.

# %%
sns.scatterplot(x = "volatile acidity", y = "alcohol", hue = "quality", data = data)
# Out:
# <Axes: xlabel='volatile acidity', ylabel='alcohol'>

# %% [markdown]
# En base al diagrama de dispersión se puede concluir que entre mayor sea la cantidad de alcohol presente en el Vino, mayor será su calidad y su acidez volátil será menor.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data[['alcohol', 'sulphates', 'volatile acidity', 'citric acid']])
plt.xticks(rotation=45)
plt.title('Boxplot Calidad del Vino')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# Después de observar el Boxplot se puede concluir que los altos niveles de alcohol en el Vino presentan niveles bajos de sulfatos, acidez volátil y ácido cítrico, además los sulfatos y la acidez volátil poseen valores atípicos en menor medida.

# %%
predictors_col = ["alcohol", "sulphates", "volatile acidity", "citric acid"]
target_col = ['quality']

# %%
predictors = data[predictors_col]
target = data[target_col]

# %%
predictors
# Out:
#       alcohol  sulphates  volatile acidity  citric acid
# 0         9.4       0.56             0.700         0.00
# 1         9.8       0.68             0.880         0.00
# 2         9.8       0.65             0.760         0.04
# 3         9.8       0.58             0.280         0.56
# 4         9.4       0.56             0.700         0.00
# ...       ...        ...               ...          ...
# 1594     10.5       0.58             0.600         0.08
# 1595     11.2       0.76             0.550         0.10
# 1596     11.0       0.75             0.510         0.13
# 1597     10.2       0.71             0.645         0.12
# 1598     11.0       0.66             0.310         0.47
#
# [1599 rows x 4 columns]

# %%
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
corr = predictors.corr()
corr
# Out:
#                    alcohol  sulphates  volatile acidity  citric acid
# alcohol           1.000000   0.093595         -0.202288     0.109903
# sulphates         0.093595   1.000000         -0.260987     0.312770
# volatile acidity -0.202288  -0.260987          1.000000    -0.552496
# citric acid       0.109903   0.312770         -0.552496     1.000000

# %% [markdown]
# Al observar la correlación entre las variables numéricas se puede indicar que aquellas que tienen un valor entre 0 y 1 poseen una correlación directa, mientras que por otro lado aquellas que indican un valor cercano a -1 poseen una correlación baja o nula, como es el caso del ácido cítrico con la acidez volátil.

# %%
sns.heatmap(corr)
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# Al observar la matriz de correlación se puede confirmar como el ácido volátil y el ácido cítrico poseen los valores más bajos de correlación, por otro lado el ácido cítrico y los sulfatos poseen los niveles más altos de correlación dentro de la matriz.

# %% [markdown]
# 4)	Dividir el dataset en Train y Test para evaluar correctamente el modelo.

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.2, random_state=13)

# %%
print (X_train)
# Out:
#       alcohol  sulphates  volatile acidity  citric acid
# 112       9.8       0.66             0.600         0.10
# 889       9.3       0.68             0.900         0.34
# 1229      9.5       0.64             0.430         0.29
# 17        9.3       1.28             0.560         0.28
# 686       9.1       0.60             0.650         0.18
# ...       ...        ...               ...          ...
# 742       9.2       0.65             0.615         0.00
# 1552     11.3       0.66             0.680         0.01
# 74        9.6       0.82             0.320         0.54
# 176       9.5       0.47             0.380         0.21
# 338      11.5       1.00             0.490         0.58
#
# [1279 rows x 4 columns]

# %%
print (X_test)
# Out:
#       alcohol  sulphates  volatile acidity  citric acid
# 912      12.2       0.62             0.460         0.44
# 1391     11.0       0.58             0.640         0.22
# 486      10.0       0.47             0.670         0.39
# 812      10.8       0.71             0.450         0.33
# 980      10.5       0.71             0.500         0.30
# ...       ...        ...               ...          ...
# 1432     11.7       0.85             0.440         0.00
# 445      10.1       0.56             0.735         0.10
# 760       9.7       0.57             0.580         0.25
# 420      11.8       0.73             0.560         0.33
# 1238      9.6       0.46             0.730         0.00
#
# [320 rows x 4 columns]

# %% [markdown]
# 5)	Entrenar el modelo configurando los diferentes hiperparámetros.

# %%
tree = DecisionTreeClassifier()

# %%
arbol = tree.fit(X_train, y_train)

# %%
plot_tree(arbol)
# Out:
# [Text(0.49409765074047957, 0.9772727272727273, 'x[0] <= 10.525\ngini = 0.646\nsamples = 1279\nvalue = [9.0, 45.0, 535.0, 514.0, 164.0, 12.0]'),
#  Text(0.15700149858956278, 0.9318181818181818, 'x[1] <= 0.535\ngini = 0.546\nsamples = 774\nvalue = [6, 29, 450, 260, 29, 0]'),
#  Text(0.32554957466502116, 0.9545454545454546, 'True  '),
#  Text(0.03674188998589563, 0.8863636363636364, 'x[2] <= 0.335\ngini = 0.367\nsamples = 183\nvalue = [2, 13, 143, 24, 1, 0]'),
#  Text(0.009026798307475317, 0.8409090909090909, 'x[3] <= 0.375\ngini = 0.562\nsamples = 11\nvalue = [0, 1, 4, 6, 0, 0]'),
#  Text(0.004513399153737658, 0.7954545454545454, 'x[3] <= 0.31\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.002256699576868829, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.006770098730606488, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.013540197461212976, 0.7954545454545454, 'x[0] <= 9.75\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 2, 6, 0, 0]'),
#  Text(0.011283497884344146, 0.75, 'x[2] <= 0.3\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.009026798307475317, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.013540197461212976, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.015796897038081806, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.06445698166431593, 0.8409090909090909, 'x[0] <= 9.533\ngini = 0.331\nsamples = 172\nvalue = [2, 12, 139, 18, 1, 0]'),
#  Text(0.031029619181946404, 0.7954545454545454, 'x[0] <= 9.075\ngini = 0.156\nsamples = 84\nvalue = [0, 4, 77, 3, 0, 0]'),
#  Text(0.020310296191819465, 0.75, 'x[2] <= 0.385\ngini = 0.611\nsamples = 6\nvalue = [0, 2, 3, 1, 0, 0]'),
#  Text(0.018053596614950634, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.022566995768688293, 0.7045454545454546, 'x[2] <= 0.605\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3, 0, 0, 0]'),
#  Text(0.020310296191819465, 0.6590909090909091, 'x[3] <= 0.39\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(0.018053596614950634, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.022566995768688293, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.024823695345557124, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.041748942172073346, 0.75, 'x[0] <= 9.35\ngini = 0.099\nsamples = 78\nvalue = [0, 2, 74, 2, 0, 0]'),
#  Text(0.039492242595204514, 0.7045454545454546, 'x[3] <= 0.295\ngini = 0.255\nsamples = 28\nvalue = [0, 2, 24, 2, 0, 0]'),
#  Text(0.03159379407616361, 0.6590909090909091, 'x[1] <= 0.525\ngini = 0.156\nsamples = 24\nvalue = [0, 1, 22, 1, 0, 0]'),
#  Text(0.027080394922425952, 0.6136363636363636, 'x[2] <= 0.53\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 21, 1, 0, 0]'),
#  Text(0.024823695345557124, 0.5681818181818182, 'x[1] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.022566995768688293, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.027080394922425952, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.02933709449929478, 0.5681818181818182, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0, 0, 0]'),
#  Text(0.03610719322990127, 0.6136363636363636, 'x[3] <= 0.25\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.03385049365303244, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0383638928067701, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.04739069111424542, 0.6590909090909091, 'x[3] <= 0.415\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 2, 1, 0, 0]'),
#  Text(0.045133991537376586, 0.6136363636363636, 'x[0] <= 9.2\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.042877291960507755, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.04739069111424542, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.04964739069111425, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.04400564174894217, 0.7045454545454546, 'gini = 0.0\nsamples = 50\nvalue = [0, 0, 50, 0, 0, 0]'),
#  Text(0.09788434414668547, 0.7954545454545454, 'x[2] <= 0.743\ngini = 0.466\nsamples = 88\nvalue = [2.0, 8.0, 62.0, 15.0, 1.0, 0.0]'),
#  Text(0.0772919605077574, 0.75, 'x[3] <= 0.245\ngini = 0.357\nsamples = 59\nvalue = [0, 1, 46, 11, 1, 0]'),
#  Text(0.06657263751763047, 0.7045454545454546, 'x[2] <= 0.613\ngini = 0.454\nsamples = 36\nvalue = [0, 1, 25, 9, 1, 0]'),
#  Text(0.05867418899858956, 0.6590909090909091, 'x[1] <= 0.495\ngini = 0.549\nsamples = 18\nvalue = [0, 1, 9, 8, 0, 0]'),
#  Text(0.054160789844851905, 0.6136363636363636, 'x[0] <= 9.85\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 8, 3, 0, 0]'),
#  Text(0.05190409026798307, 0.5681818181818182, 'x[3] <= 0.09\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.04964739069111425, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.054160789844851905, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.056417489421720736, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.06318758815232722, 0.6136363636363636, 'x[3] <= 0.215\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 1, 5, 0, 0]'),
#  Text(0.06093088857545839, 0.5681818181818182, 'x[1] <= 0.515\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.05867418899858956, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.06318758815232722, 0.5227272727272727, 'x[2] <= 0.585\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.06093088857545839, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.06544428772919605, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.06544428772919605, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.07447108603667137, 0.6590909090909091, 'x[3] <= 0.01\ngini = 0.204\nsamples = 18\nvalue = [0, 0, 16, 1, 1, 0]'),
#  Text(0.07221438645980253, 0.6136363636363636, 'x[1] <= 0.495\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 1, 0]'),
#  Text(0.0699576868829337, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.07447108603667137, 0.5681818181818182, 'x[2] <= 0.657\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.07221438645980253, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0767277856135402, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0767277856135402, 0.6136363636363636, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.08801128349788434, 0.7045454545454546, 'x[1] <= 0.425\ngini = 0.159\nsamples = 23\nvalue = [0, 0, 21, 2, 0, 0]'),
#  Text(0.08349788434414669, 0.6590909090909091, 'x[3] <= 0.31\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.08124118476727786, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.08575458392101551, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.092524682651622, 0.6590909090909091, 'x[0] <= 10.45\ngini = 0.091\nsamples = 21\nvalue = [0, 0, 20, 1, 0, 0]'),
#  Text(0.09026798307475317, 0.6136363636363636, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 18, 0, 0, 0]'),
#  Text(0.09478138222849083, 0.6136363636363636, 'x[2] <= 0.44\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.092524682651622, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.09703808180535967, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.11847672778561354, 0.75, 'x[0] <= 9.85\ngini = 0.614\nsamples = 29\nvalue = [2, 7, 16, 4, 0, 0]'),
#  Text(0.10832157968970381, 0.7045454545454546, 'x[3] <= 0.135\ngini = 0.702\nsamples = 15\nvalue = [1, 5, 5, 4, 0, 0]'),
#  Text(0.10155148095909731, 0.6590909090909091, 'x[2] <= 0.797\ngini = 0.593\nsamples = 9\nvalue = [1, 4, 4, 0, 0, 0]'),
#  Text(0.0992947813822285, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.10380818053596615, 0.6136363636363636, 'x[2] <= 0.912\ngini = 0.571\nsamples = 7\nvalue = [1, 2, 4, 0, 0, 0]'),
#  Text(0.10155148095909731, 0.5681818181818182, 'x[1] <= 0.505\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 4, 0, 0, 0]'),
#  Text(0.0992947813822285, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.10380818053596615, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.10606488011283498, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.11509167842031029, 0.6590909090909091, 'x[2] <= 0.808\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 1, 4, 0, 0]'),
#  Text(0.11283497884344147, 0.6136363636363636, 'x[3] <= 0.205\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.11057827926657264, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.11509167842031029, 0.5681818181818182, 'x[3] <= 0.27\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.11283497884344147, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.11734837799717912, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.11734837799717912, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.12863187588152328, 0.7045454545454546, 'x[0] <= 10.1\ngini = 0.357\nsamples = 14\nvalue = [1, 2, 11, 0, 0, 0]'),
#  Text(0.12411847672778561, 0.6590909090909091, 'x[3] <= 0.235\ngini = 0.165\nsamples = 11\nvalue = [0, 1, 10, 0, 0, 0]'),
#  Text(0.12186177715091678, 0.6136363636363636, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.12637517630465445, 0.6136363636363636, 'x[1] <= 0.495\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.12411847672778561, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.12863187588152328, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.13314527503526094, 0.6590909090909091, 'x[2] <= 0.947\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 1, 0, 0, 0]'),
#  Text(0.1308885754583921, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.13540197461212977, 0.6136363636363636, 'x[2] <= 1.1\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.13314527503526094, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1376586741889986, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2772611071932299, 0.8863636363636364, 'x[2] <= 0.365\ngini = 0.568\nsamples = 591\nvalue = [4, 16, 307, 236, 28, 0]'),
#  Text(0.16868829337094499, 0.8409090909090909, 'x[1] <= 0.655\ngini = 0.517\nsamples = 76\nvalue = [0, 1, 18, 49, 8, 0]'),
#  Text(0.1545839210155148, 0.7954545454545454, 'x[2] <= 0.355\ngini = 0.538\nsamples = 25\nvalue = [0, 1, 12, 12, 0, 0]'),
#  Text(0.152327221438646, 0.75, 'x[0] <= 9.35\ngini = 0.526\nsamples = 21\nvalue = [0, 1, 12, 8, 0, 0]'),
#  Text(0.15007052186177716, 0.7045454545454546, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.1545839210155148, 0.7045454545454546, 'x[1] <= 0.595\ngini = 0.549\nsamples = 18\nvalue = [0, 1, 9, 8, 0, 0]'),
#  Text(0.14894217207334273, 0.6590909090909091, 'x[1] <= 0.585\ngini = 0.562\nsamples = 11\nvalue = [0, 1, 4, 6, 0, 0]'),
#  Text(0.1466854724964739, 0.6136363636363636, 'x[0] <= 9.7\ngini = 0.593\nsamples = 9\nvalue = [0, 1, 4, 4, 0, 0]'),
#  Text(0.14217207334273624, 0.5681818181818182, 'x[3] <= 0.355\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.1399153737658674, 0.5227272727272727, 'x[3] <= 0.235\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.1376586741889986, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.14217207334273624, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.14442877291960507, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.15119887165021156, 0.5681818181818182, 'x[2] <= 0.345\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 1, 3, 0, 0]'),
#  Text(0.14894217207334273, 0.5227272727272727, 'x[3] <= 0.275\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.1466854724964739, 0.4772727272727273, 'x[3] <= 0.225\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.14442877291960507, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.14894217207334273, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.15119887165021156, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.1534555712270804, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.15119887165021156, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.1602256699576869, 0.6590909090909091, 'x[2] <= 0.21\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.15796897038081806, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.16248236953455572, 0.6136363636363636, 'x[1] <= 0.615\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.1602256699576869, 0.5681818181818182, 'x[0] <= 10.25\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.15796897038081806, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.16248236953455572, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.16473906911142455, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.15684062059238363, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.18279266572637518, 0.7954545454545454, 'x[3] <= 0.535\ngini = 0.435\nsamples = 51\nvalue = [0, 0, 6, 37, 8, 0]'),
#  Text(0.17602256699576868, 0.75, 'x[3] <= 0.15\ngini = 0.335\nsamples = 40\nvalue = [0, 0, 2, 32, 6, 0]'),
#  Text(0.17376586741889985, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.1782792665726375, 0.7045454545454546, 'x[2] <= 0.3\ngini = 0.308\nsamples = 39\nvalue = [0, 0, 2, 32, 5, 0]'),
#  Text(0.17602256699576868, 0.6590909090909091, 'x[0] <= 9.25\ngini = 0.412\nsamples = 27\nvalue = [0, 0, 2, 20, 5, 0]'),
#  Text(0.17150916784203102, 0.6136363636363636, 'x[1] <= 0.855\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.1692524682651622, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.17376586741889985, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.18053596614950634, 0.6136363636363636, 'x[1] <= 0.665\ngini = 0.351\nsamples = 24\nvalue = [0, 0, 2, 19, 3, 0]'),
#  Text(0.1782792665726375, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.18279266572637518, 0.5681818181818182, 'x[3] <= 0.515\ngini = 0.302\nsamples = 23\nvalue = [0, 0, 2, 19, 2, 0]'),
#  Text(0.18053596614950634, 0.5227272727272727, 'x[3] <= 0.415\ngini = 0.244\nsamples = 22\nvalue = [0, 0, 2, 19, 1, 0]'),
#  Text(0.1782792665726375, 0.4772727272727273, 'x[3] <= 0.385\ngini = 0.46\nsamples = 10\nvalue = [0, 0, 2, 7, 1, 0]'),
#  Text(0.17602256699576868, 0.4318181818181818, 'x[2] <= 0.245\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 7, 1, 0]'),
#  Text(0.17376586741889985, 0.38636363636363635, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.1782792665726375, 0.38636363636363635, 'x[2] <= 0.255\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.17602256699576868, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.18053596614950634, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.18053596614950634, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.18279266572637518, 0.4772727272727273, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.185049365303244, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.18053596614950634, 0.6590909090909091, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.18956276445698167, 0.75, 'x[2] <= 0.317\ngini = 0.628\nsamples = 11\nvalue = [0, 0, 4, 5, 2, 0]'),
#  Text(0.18730606488011284, 0.7045454545454546, 'x[0] <= 10.3\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 2, 0]'),
#  Text(0.185049365303244, 0.6590909090909091, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.18956276445698167, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.1918194640338505, 0.7045454545454546, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.38583392101551484, 0.8409090909090909, 'x[0] <= 9.85\ngini = 0.551\nsamples = 515\nvalue = [4, 15, 289, 187, 20, 0]'),
#  Text(0.29472849083215796, 0.7954545454545454, 'x[2] <= 0.555\ngini = 0.489\nsamples = 330\nvalue = [2, 9, 212, 103, 4, 0]'),
#  Text(0.24106135401974613, 0.75, 'x[1] <= 0.585\ngini = 0.526\nsamples = 150\nvalue = [0.0, 3.0, 84.0, 60.0, 3.0, 0.0]'),
#  Text(0.19633286318758816, 0.7045454545454546, 'x[3] <= 0.045\ngini = 0.316\nsamples = 37\nvalue = [0, 1, 30, 6, 0, 0]'),
#  Text(0.19407616361071933, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.198589562764457, 0.6590909090909091, 'x[1] <= 0.565\ngini = 0.285\nsamples = 36\nvalue = [0, 1, 30, 5, 0, 0]'),
#  Text(0.1929478138222849, 0.6136363636363636, 'x[0] <= 9.1\ngini = 0.375\nsamples = 20\nvalue = [0, 0, 15, 5, 0, 0]'),
#  Text(0.19069111424541607, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.19520451339915373, 0.5681818181818182, 'x[3] <= 0.235\ngini = 0.332\nsamples = 19\nvalue = [0, 0, 15, 4, 0, 0]'),
#  Text(0.1929478138222849, 0.5227272727272727, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.19746121297602257, 0.5227272727272727, 'x[3] <= 0.32\ngini = 0.408\nsamples = 14\nvalue = [0, 0, 10, 4, 0, 0]'),
#  Text(0.1929478138222849, 0.4772727272727273, 'x[2] <= 0.435\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]'),
#  Text(0.19069111424541607, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.19520451339915373, 0.4318181818181818, 'x[2] <= 0.525\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.1929478138222849, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.19746121297602257, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.20197461212976023, 0.4772727272727273, 'x[1] <= 0.555\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(0.1997179125528914, 0.4318181818181818, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.20423131170662906, 0.4318181818181818, 'x[0] <= 9.3\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.20197461212976023, 0.38636363636363635, 'x[3] <= 0.355\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.1997179125528914, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.20423131170662906, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2064880112834979, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.20423131170662906, 0.6136363636363636, 'x[0] <= 9.55\ngini = 0.117\nsamples = 16\nvalue = [0, 1, 15, 0, 0, 0]'),
#  Text(0.20197461212976023, 0.5681818181818182, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.2064880112834979, 0.5681818181818182, 'x[3] <= 0.435\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.20423131170662906, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.20874471086036672, 0.5227272727272727, 'x[2] <= 0.455\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.2064880112834979, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.21100141043723555, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.2857898448519041, 0.7045454545454546, 'x[1] <= 1.065\ngini = 0.542\nsamples = 113\nvalue = [0, 2, 54, 54, 3, 0]'),
#  Text(0.26918194640338505, 0.6590909090909091, 'x[1] <= 0.675\ngini = 0.534\nsamples = 104\nvalue = [0.0, 1.0, 46.0, 54.0, 3.0, 0.0]'),
#  Text(0.24273624823695344, 0.6136363636363636, 'x[1] <= 0.605\ngini = 0.523\nsamples = 72\nvalue = [0, 0, 38, 32, 2, 0]'),
#  Text(0.22679830747531735, 0.5681818181818182, 'x[0] <= 9.6\ngini = 0.499\nsamples = 19\nvalue = [0, 0, 6, 12, 1, 0]'),
#  Text(0.21777150916784202, 0.5227272727272727, 'x[3] <= 0.315\ngini = 0.337\nsamples = 14\nvalue = [0, 0, 3, 11, 0, 0]'),
#  Text(0.2155148095909732, 0.4772727272727273, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.22002820874471085, 0.4772727272727273, 'x[3] <= 0.345\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.21777150916784202, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.22228490832157968, 0.4318181818181818, 'x[3] <= 0.485\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.22002820874471085, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.22454160789844851, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23582510578279267, 0.5227272727272727, 'x[2] <= 0.545\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 3, 1, 1, 0]'),
#  Text(0.23356840620592384, 0.4772727272727273, 'x[2] <= 0.51\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.231311706629055, 0.4318181818181818, 'x[3] <= 0.365\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.22905500705218618, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.23356840620592384, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23582510578279267, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2380818053596615, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25867418899858957, 0.5681818181818182, 'x[3] <= 0.255\ngini = 0.493\nsamples = 53\nvalue = [0, 0, 32, 20, 1, 0]'),
#  Text(0.2471086036671368, 0.5227272727272727, 'x[2] <= 0.53\ngini = 0.533\nsamples = 22\nvalue = [0, 0, 9, 12, 1, 0]'),
#  Text(0.24259520451339917, 0.4772727272727273, 'x[1] <= 0.665\ngini = 0.461\nsamples = 16\nvalue = [0, 0, 4, 11, 1, 0]'),
#  Text(0.24033850493653033, 0.4318181818181818, 'x[2] <= 0.455\ngini = 0.418\nsamples = 15\nvalue = [0, 0, 3, 11, 1, 0]'),
#  Text(0.2380818053596615, 0.38636363636363635, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.24259520451339917, 0.38636363636363635, 'x[2] <= 0.485\ngini = 0.54\nsamples = 10\nvalue = [0, 0, 3, 6, 1, 0]'),
#  Text(0.24033850493653033, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.244851904090268, 0.3409090909090909, 'x[1] <= 0.625\ngini = 0.406\nsamples = 8\nvalue = [0, 0, 1, 6, 1, 0]'),
#  Text(0.24259520451339917, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2471086036671368, 0.29545454545454547, 'x[1] <= 0.635\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.244851904090268, 0.25, 'x[2] <= 0.51\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.24259520451339917, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2471086036671368, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.24936530324400563, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.244851904090268, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2516220028208745, 0.4772727272727273, 'x[3] <= 0.065\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.24936530324400563, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2538787023977433, 0.4318181818181818, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.2702397743300423, 0.5227272727272727, 'x[2] <= 0.412\ngini = 0.383\nsamples = 31\nvalue = [0, 0, 23, 8, 0, 0]'),
#  Text(0.26064880112834976, 0.4772727272727273, 'x[3] <= 0.405\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(0.25839210155148096, 0.4318181818181818, 'x[0] <= 9.35\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.25613540197461215, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.26064880112834976, 0.38636363636363635, 'x[3] <= 0.305\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.25839210155148096, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2629055007052186, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2629055007052186, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.2798307475317348, 0.4772727272727273, 'x[1] <= 0.635\ngini = 0.287\nsamples = 23\nvalue = [0, 0, 19, 4, 0, 0]'),
#  Text(0.277574047954866, 0.4318181818181818, 'x[1] <= 0.625\ngini = 0.375\nsamples = 16\nvalue = [0, 0, 12, 4, 0, 0]'),
#  Text(0.27193229901269395, 0.38636363636363635, 'x[2] <= 0.44\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 11, 2, 0, 0]'),
#  Text(0.2674188998589563, 0.3409090909090909, 'x[2] <= 0.425\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2651622002820874, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2696755994358251, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2764456981664316, 0.3409090909090909, 'x[3] <= 0.47\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 10, 1, 0, 0]'),
#  Text(0.27418899858956275, 0.29545454545454547, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.2787023977433004, 0.29545454545454547, 'x[0] <= 9.3\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2764456981664316, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.28095909732016927, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2832157968970381, 0.38636363636363635, 'x[0] <= 9.55\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.28095909732016927, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.28547249647390693, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2820874471086037, 0.4318181818181818, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.29562764456981666, 0.6136363636363636, 'x[1] <= 0.735\ngini = 0.463\nsamples = 32\nvalue = [0, 1, 8, 22, 1, 0]'),
#  Text(0.2843441466854725, 0.5681818181818182, 'x[3] <= 0.24\ngini = 0.37\nsamples = 9\nvalue = [0, 1, 0, 7, 1, 0]'),
#  Text(0.2820874471086037, 0.5227272727272727, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.28660084626234134, 0.5227272727272727, 'x[1] <= 0.69\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 0, 2, 1, 0]'),
#  Text(0.2843441466854725, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.28885754583921014, 0.4772727272727273, 'x[3] <= 0.38\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.28660084626234134, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.291114245416079, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3069111424541608, 0.5681818181818182, 'x[2] <= 0.535\ngini = 0.454\nsamples = 23\nvalue = [0, 0, 8, 15, 0, 0]'),
#  Text(0.304654442877292, 0.5227272727272727, 'x[2] <= 0.44\ngini = 0.494\nsamples = 18\nvalue = [0, 0, 8, 10, 0, 0]'),
#  Text(0.29788434414668546, 0.4772727272727273, 'x[1] <= 0.985\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.29562764456981666, 0.4318181818181818, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.3001410437235543, 0.4318181818181818, 'x[0] <= 9.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.29788434414668546, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3023977433004231, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.31142454160789845, 0.4772727272727273, 'x[3] <= 0.27\ngini = 0.42\nsamples = 10\nvalue = [0, 0, 7, 3, 0, 0]'),
#  Text(0.3091678420310296, 0.4318181818181818, 'x[0] <= 9.55\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.3069111424541608, 0.38636363636363635, 'x[3] <= 0.19\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.304654442877292, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3091678420310296, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.31142454160789845, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.31368124118476726, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.3091678420310296, 0.5227272727272727, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.3023977433004231, 0.6590909090909091, 'x[1] <= 1.99\ngini = 0.198\nsamples = 9\nvalue = [0, 1, 8, 0, 0, 0]'),
#  Text(0.3001410437235543, 0.6136363636363636, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.304654442877292, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3483956276445698, 0.75, 'x[0] <= 9.15\ngini = 0.436\nsamples = 180\nvalue = [2, 6, 128, 43, 1, 0]'),
#  Text(0.3215796897038082, 0.7045454545454546, 'x[1] <= 0.625\ngini = 0.561\nsamples = 17\nvalue = [1, 1, 5, 10, 0, 0]'),
#  Text(0.3159379407616361, 0.6590909090909091, 'x[2] <= 1.035\ngini = 0.375\nsamples = 12\nvalue = [0, 0, 3, 9, 0, 0]'),
#  Text(0.31368124118476726, 0.6136363636363636, 'x[0] <= 9.05\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 2, 9, 0, 0]'),
#  Text(0.31142454160789845, 0.5681818181818182, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.3159379407616361, 0.5681818181818182, 'x[1] <= 0.61\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.31368124118476726, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3181946403385049, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3181946403385049, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.32722143864598024, 0.6590909090909091, 'x[2] <= 0.618\ngini = 0.72\nsamples = 5\nvalue = [1, 1, 2, 1, 0, 0]'),
#  Text(0.3227080394922426, 0.6136363636363636, 'x[0] <= 8.7\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2, 0, 0, 0]'),
#  Text(0.3204513399153738, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.32496473906911144, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3317348377997179, 0.6136363636363636, 'x[3] <= 0.44\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.3294781382228491, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.33399153737658677, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3752115655853315, 0.7045454545454546, 'x[2] <= 0.963\ngini = 0.389\nsamples = 163\nvalue = [1, 5, 123, 33, 1, 0]'),
#  Text(0.3648095909732017, 0.6590909090909091, 'x[2] <= 0.692\ngini = 0.374\nsamples = 161\nvalue = [0.0, 4.0, 123.0, 33.0, 1.0, 0.0]'),
#  Text(0.3507757404795487, 0.6136363636363636, 'x[3] <= 0.085\ngini = 0.414\nsamples = 124\nvalue = [0, 3, 90, 30, 1, 0]'),
#  Text(0.3385049365303244, 0.5681818181818182, 'x[3] <= 0.075\ngini = 0.502\nsamples = 47\nvalue = [0, 1, 29, 16, 1, 0]'),
#  Text(0.33399153737658677, 0.5227272727272727, 'x[1] <= 0.96\ngini = 0.473\nsamples = 42\nvalue = [0, 1, 28, 12, 1, 0]'),
#  Text(0.3317348377997179, 0.4772727272727273, 'x[0] <= 9.75\ngini = 0.447\nsamples = 41\nvalue = [0.0, 0.0, 28.0, 12.0, 1.0, 0.0]'),
#  Text(0.3294781382228491, 0.4318181818181818, 'x[3] <= 0.025\ngini = 0.487\nsamples = 35\nvalue = [0, 0, 22, 12, 1, 0]'),
#  Text(0.32496473906911144, 0.38636363636363635, 'x[1] <= 0.675\ngini = 0.537\nsamples = 23\nvalue = [0, 0, 12, 10, 1, 0]'),
#  Text(0.3227080394922426, 0.3409090909090909, 'x[2] <= 0.655\ngini = 0.508\nsamples = 16\nvalue = [0, 0, 5, 10, 1, 0]'),
#  Text(0.3170662905500705, 0.29545454545454547, 'x[1] <= 0.575\ngini = 0.314\nsamples = 11\nvalue = [0, 0, 1, 9, 1, 0]'),
#  Text(0.31255289139633285, 0.25, 'x[1] <= 0.56\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.31029619181946405, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3148095909732017, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3215796897038082, 0.25, 'x[0] <= 9.25\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]'),
#  Text(0.3193229901269394, 0.20454545454545456, 'x[1] <= 0.615\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3170662905500705, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3215796897038082, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.323836389280677, 0.20454545454545456, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.32834978843441465, 0.29545454545454547, 'x[2] <= 0.688\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.32609308885754584, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3306064880112835, 0.25, 'x[0] <= 9.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.32834978843441465, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3328631875881523, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.32722143864598024, 0.3409090909090909, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.33399153737658677, 0.38636363636363635, 'x[2] <= 0.585\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2, 0, 0]'),
#  Text(0.3317348377997179, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.33624823695345557, 0.3409090909090909, 'x[1] <= 0.745\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 10, 1, 0, 0]'),
#  Text(0.33399153737658677, 0.29545454545454547, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.3385049365303244, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.33399153737658677, 0.4318181818181818, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.33624823695345557, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.34301833568406204, 0.5227272727272727, 'x[2] <= 0.6\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.34076163610719323, 0.4772727272727273, 'x[2] <= 0.57\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3385049365303244, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.34301833568406204, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3452750352609309, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.36304654442877293, 0.5681818181818182, 'x[0] <= 9.75\ngini = 0.339\nsamples = 77\nvalue = [0, 2, 61, 14, 0, 0]'),
#  Text(0.35853314527503527, 0.5227272727272727, 'x[1] <= 1.445\ngini = 0.286\nsamples = 66\nvalue = [0, 2, 55, 9, 0, 0]'),
#  Text(0.3562764456981664, 0.4772727272727273, 'x[1] <= 0.705\ngini = 0.268\nsamples = 65\nvalue = [0, 2, 55, 8, 0, 0]'),
#  Text(0.3540197461212976, 0.4318181818181818, 'x[1] <= 0.68\ngini = 0.318\nsamples = 53\nvalue = [0, 2, 43, 8, 0, 0]'),
#  Text(0.35176304654442875, 0.38636363636363635, 'x[0] <= 9.25\ngini = 0.249\nsamples = 50\nvalue = [0, 2, 43, 5, 0, 0]'),
#  Text(0.3452750352609309, 0.3409090909090909, 'x[2] <= 0.645\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.34301833568406204, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3475317348377997, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.35825105782792666, 0.3409090909090909, 'x[1] <= 0.585\ngini = 0.223\nsamples = 48\nvalue = [0, 1, 42, 5, 0, 0]'),
#  Text(0.35204513399153736, 0.29545454545454547, 'x[1] <= 0.575\ngini = 0.344\nsamples = 24\nvalue = [0, 1, 19, 4, 0, 0]'),
#  Text(0.3464033850493653, 0.25, 'x[3] <= 0.45\ngini = 0.265\nsamples = 20\nvalue = [0, 1, 17, 2, 0, 0]'),
#  Text(0.34188998589562763, 0.20454545454545456, 'x[1] <= 0.545\ngini = 0.198\nsamples = 18\nvalue = [0, 0, 16, 2, 0, 0]'),
#  Text(0.33963328631875883, 0.1590909090909091, 'x[3] <= 0.235\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.33737658674188997, 0.11363636363636363, 'x[2] <= 0.65\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.33511988716502117, 0.06818181818181818, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.33963328631875883, 0.06818181818181818, 'x[2] <= 0.665\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.33737658674188997, 0.022727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.34188998589562763, 0.022727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.34188998589562763, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3441466854724965, 0.1590909090909091, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.35091678420310296, 0.20454545454545456, 'x[2] <= 0.595\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.34866008462623416, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.35317348377997176, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3576868829337094, 0.25, 'x[2] <= 0.595\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.3554301833568406, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3599435825105783, 0.20454545454545456, 'x[0] <= 9.45\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.3576868829337094, 0.1590909090909091, 'x[2] <= 0.615\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3554301833568406, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3599435825105783, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3622002820874471, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.36445698166431595, 0.29545454545454547, 'x[2] <= 0.68\ngini = 0.08\nsamples = 24\nvalue = [0, 0, 23, 1, 0, 0]'),
#  Text(0.3622002820874471, 0.25, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 21, 0, 0, 0]'),
#  Text(0.36671368124118475, 0.25, 'x[1] <= 0.635\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.36445698166431595, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3689703808180536, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3562764456981664, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.35853314527503527, 0.4318181818181818, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.3607898448519041, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3675599435825106, 0.5227272727272727, 'x[1] <= 0.585\ngini = 0.496\nsamples = 11\nvalue = [0, 0, 6, 5, 0, 0]'),
#  Text(0.36530324400564174, 0.4772727272727273, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.3698166431593794, 0.4772727272727273, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.3788434414668547, 0.6136363636363636, 'x[1] <= 0.545\ngini = 0.197\nsamples = 37\nvalue = [0, 1, 33, 3, 0, 0]'),
#  Text(0.37433004231311706, 0.5681818181818182, 'x[2] <= 0.718\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 3, 1, 0, 0]'),
#  Text(0.37207334273624826, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3765867418899859, 0.5227272727272727, 'x[2] <= 0.745\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.37433004231311706, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3788434414668547, 0.4772727272727273, 'x[3] <= 0.14\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.3765867418899859, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.38110014104372353, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3833568406205924, 0.5681818181818182, 'x[2] <= 0.782\ngini = 0.117\nsamples = 32\nvalue = [0, 0, 30, 2, 0, 0]'),
#  Text(0.38110014104372353, 0.5227272727272727, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 24, 0, 0, 0]'),
#  Text(0.3856135401974612, 0.5227272727272727, 'x[1] <= 0.705\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 6, 2, 0, 0]'),
#  Text(0.3833568406205924, 0.4772727272727273, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.38787023977433005, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3856135401974612, 0.6590909090909091, 'x[0] <= 9.55\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]'),
#  Text(0.3833568406205924, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.38787023977433005, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.47693935119887165, 0.7954545454545454, 'x[3] <= 0.315\ngini = 0.612\nsamples = 185\nvalue = [2, 6, 77, 84, 16, 0]'),
#  Text(0.44160789844851905, 0.75, 'x[2] <= 0.655\ngini = 0.563\nsamples = 126\nvalue = [1, 2, 49, 67, 7, 0]'),
#  Text(0.4045133991537377, 0.7045454545454546, 'x[0] <= 9.95\ngini = 0.52\nsamples = 85\nvalue = [0, 1, 25, 53, 6, 0]'),
#  Text(0.4022566995768688, 0.6590909090909091, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.4067700987306065, 0.6590909090909091, 'x[2] <= 0.405\ngini = 0.547\nsamples = 77\nvalue = [0, 1, 25, 45, 6, 0]'),
#  Text(0.3935119887165021, 0.6136363636363636, 'x[1] <= 0.665\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.3912552891396333, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3957686882933709, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.42002820874471086, 0.6136363636363636, 'x[2] <= 0.565\ngini = 0.529\nsamples = 74\nvalue = [0, 1, 25, 44, 4, 0]'),
#  Text(0.4002820874471086, 0.5681818181818182, 'x[3] <= 0.075\ngini = 0.429\nsamples = 45\nvalue = [0, 0, 14, 31, 0, 0]'),
#  Text(0.3946403385049365, 0.5227272727272727, 'x[0] <= 10.15\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 1, 9, 0, 0]'),
#  Text(0.3923836389280677, 0.4772727272727273, 'x[2] <= 0.525\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.39012693935119885, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3946403385049365, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3968970380818054, 0.4772727272727273, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.4059238363892807, 0.5227272727272727, 'x[3] <= 0.195\ngini = 0.467\nsamples = 35\nvalue = [0, 0, 13, 22, 0, 0]'),
#  Text(0.40141043723554304, 0.4772727272727273, 'x[2] <= 0.425\ngini = 0.49\nsamples = 14\nvalue = [0, 0, 8, 6, 0, 0]'),
#  Text(0.3991537376586742, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.40366713681241184, 0.4318181818181818, 'x[1] <= 0.635\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 8, 3, 0, 0]'),
#  Text(0.40141043723554304, 0.38636363636363635, 'x[3] <= 0.145\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.3991537376586742, 0.3409090909090909, 'x[2] <= 0.495\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.3968970380818054, 0.29545454545454547, 'x[2] <= 0.475\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3946403385049365, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3991537376586742, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.40141043723554304, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.40366713681241184, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4059238363892807, 0.38636363636363635, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.4104372355430183, 0.4772727272727273, 'x[1] <= 0.545\ngini = 0.363\nsamples = 21\nvalue = [0, 0, 5, 16, 0, 0]'),
#  Text(0.4081805359661495, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.41269393511988717, 0.4318181818181818, 'x[1] <= 0.59\ngini = 0.32\nsamples = 20\nvalue = [0, 0, 4, 16, 0, 0]'),
#  Text(0.4104372355430183, 0.38636363636363635, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.41495063469675597, 0.38636363636363635, 'x[1] <= 0.605\ngini = 0.426\nsamples = 13\nvalue = [0, 0, 4, 9, 0, 0]'),
#  Text(0.41269393511988717, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.41720733427362483, 0.3409090909090909, 'x[0] <= 10.05\ngini = 0.375\nsamples = 12\nvalue = [0, 0, 3, 9, 0, 0]'),
#  Text(0.41495063469675597, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.41946403385049363, 0.29545454545454547, 'x[2] <= 0.555\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 3, 6, 0, 0]'),
#  Text(0.41720733427362483, 0.25, 'x[1] <= 0.625\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 2, 6, 0, 0]'),
#  Text(0.41495063469675597, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.41946403385049363, 0.20454545454545456, 'x[1] <= 0.94\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.41720733427362483, 0.1590909090909091, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.4217207334273625, 0.1590909090909091, 'x[3] <= 0.28\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.41946403385049363, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4239774330042313, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4217207334273625, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.43977433004231314, 0.5681818181818182, 'x[1] <= 0.66\ngini = 0.635\nsamples = 29\nvalue = [0, 1, 11, 13, 4, 0]'),
#  Text(0.4307475317348378, 0.5227272727272727, 'x[1] <= 0.575\ngini = 0.566\nsamples = 22\nvalue = [0, 1, 6, 13, 2, 0]'),
#  Text(0.42623413258110016, 0.4772727272727273, 'x[0] <= 10.3\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.4239774330042313, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.42849083215796896, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.4352609308885755, 0.4772727272727273, 'x[0] <= 10.45\ngini = 0.426\nsamples = 18\nvalue = [0, 1, 4, 13, 0, 0]'),
#  Text(0.4330042313117066, 0.4318181818181818, 'x[2] <= 0.595\ngini = 0.381\nsamples = 17\nvalue = [0, 1, 3, 13, 0, 0]'),
#  Text(0.42849083215796896, 0.38636363636363635, 'x[1] <= 0.62\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 3, 5, 0, 0]'),
#  Text(0.42623413258110016, 0.3409090909090909, 'x[0] <= 10.25\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.4239774330042313, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.42849083215796896, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
# ...
#  Text(0.8346967559943582, 0.8409090909090909, 'x[0] <= 11.15\ngini = 0.696\nsamples = 23\nvalue = [3, 6, 10, 4, 0, 0]'),
#  Text(0.8251057827926658, 0.7954545454545454, 'x[1] <= 0.56\ngini = 0.653\nsamples = 14\nvalue = [3, 1, 7, 3, 0, 0]'),
#  Text(0.8194640338504936, 0.75, 'x[2] <= 0.99\ngini = 0.512\nsamples = 11\nvalue = [3, 0, 7, 1, 0, 0]'),
#  Text(0.814950634696756, 0.7045454545454546, 'x[1] <= 0.435\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.8126939351198872, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8172073342736248, 0.6590909090909091, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.8239774330042313, 0.7045454545454546, 'x[2] <= 1.257\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 2, 0, 0, 0]'),
#  Text(0.8217207334273625, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.8262341325811001, 0.6590909090909091, 'x[1] <= 0.44\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2, 0, 0, 0]'),
#  Text(0.8239774330042313, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.8284908321579689, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8307475317348378, 0.75, 'x[3] <= 0.05\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.8284908321579689, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8330042313117066, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8442877291960508, 0.7954545454545454, 'x[1] <= 0.61\ngini = 0.568\nsamples = 9\nvalue = [0, 5, 3, 1, 0, 0]'),
#  Text(0.8397743300423132, 0.75, 'x[1] <= 0.48\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 0, 1, 0, 0]'),
#  Text(0.8375176304654443, 0.7045454545454546, 'x[0] <= 11.3\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.8352609308885754, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8397743300423132, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.842031029619182, 0.7045454545454546, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.8488011283497884, 0.75, 'x[1] <= 0.655\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.8465444287729196, 0.7045454545454546, 'x[0] <= 11.4\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.8442877291960508, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8488011283497884, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8510578279266573, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.901410437235543, 0.8863636363636364, 'x[2] <= 0.335\ngini = 0.604\nsamples = 156\nvalue = [0, 0, 14, 64, 73, 5]'),
#  Text(0.86262341325811, 0.8409090909090909, 'x[3] <= 0.295\ngini = 0.464\nsamples = 52\nvalue = [0, 0, 2, 12, 36, 2]'),
#  Text(0.8581100141043724, 0.7954545454545454, 'x[0] <= 10.75\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.8558533145275036, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8603667136812412, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8671368124118477, 0.7954545454545454, 'x[1] <= 0.765\ngini = 0.416\nsamples = 49\nvalue = [0.0, 0.0, 1.0, 10.0, 36.0, 2.0]'),
#  Text(0.8648801128349789, 0.75, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(0.8693935119887165, 0.75, 'x[2] <= 0.265\ngini = 0.471\nsamples = 41\nvalue = [0.0, 0.0, 1.0, 10.0, 28.0, 2.0]'),
#  Text(0.8555712270803949, 0.7045454545454546, 'x[3] <= 0.475\ngini = 0.497\nsamples = 13\nvalue = [0, 0, 0, 6, 7, 0]'),
#  Text(0.8533145275035261, 0.6590909090909091, 'x[3] <= 0.35\ngini = 0.463\nsamples = 11\nvalue = [0, 0, 0, 4, 7, 0]'),
#  Text(0.8488011283497884, 0.6136363636363636, 'x[2] <= 0.25\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.8465444287729196, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8510578279266573, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8578279266572637, 0.6136363636363636, 'x[0] <= 10.7\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(0.8555712270803949, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8600846262341326, 0.5681818181818182, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.8578279266572637, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8832157968970381, 0.7045454545454546, 'x[3] <= 0.555\ngini = 0.411\nsamples = 28\nvalue = [0, 0, 1, 4, 21, 2]'),
#  Text(0.87475317348378, 0.6590909090909091, 'x[0] <= 12.55\ngini = 0.299\nsamples = 23\nvalue = [0, 0, 0, 3, 19, 1]'),
#  Text(0.869111424541608, 0.6136363636363636, 'x[1] <= 0.775\ngini = 0.245\nsamples = 21\nvalue = [0, 0, 0, 3, 18, 0]'),
#  Text(0.8645980253878702, 0.5681818181818182, 'x[2] <= 0.315\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.8623413258110014, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.866854724964739, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8736248236953456, 0.5681818181818182, 'x[3] <= 0.43\ngini = 0.188\nsamples = 19\nvalue = [0, 0, 0, 2, 17, 0]'),
#  Text(0.8713681241184768, 0.5227272727272727, 'x[3] <= 0.405\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 0, 2, 8, 0]'),
#  Text(0.869111424541608, 0.4772727272727273, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.8736248236953456, 0.4772727272727273, 'x[3] <= 0.415\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.8713681241184768, 0.4318181818181818, 'x[2] <= 0.305\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.869111424541608, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8736248236953456, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8758815232722144, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8758815232722144, 0.5227272727272727, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 0, 9, 0]'),
#  Text(0.8803949224259521, 0.6136363636363636, 'x[1] <= 0.795\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.8781382228490832, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8826516220028209, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8916784203102962, 0.6590909090909091, 'x[3] <= 0.685\ngini = 0.72\nsamples = 5\nvalue = [0, 0, 1, 1, 2, 1]'),
#  Text(0.8894217207334274, 0.6136363636363636, 'x[3] <= 0.565\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 0, 1]'),
#  Text(0.8871650211565585, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8916784203102962, 0.5681818181818182, 'x[1] <= 0.785\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8894217207334274, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.893935119887165, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.893935119887165, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.940197461212976, 0.8409090909090909, 'x[0] <= 11.45\ngini = 0.609\nsamples = 104\nvalue = [0, 0, 12, 52, 37, 3]'),
#  Text(0.9052186177715091, 0.7954545454545454, 'x[1] <= 0.745\ngini = 0.519\nsamples = 51\nvalue = [0, 0, 9, 33, 9, 0]'),
#  Text(0.9029619181946403, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.907475317348378, 0.75, 'x[1] <= 0.775\ngini = 0.492\nsamples = 49\nvalue = [0, 0, 7, 33, 9, 0]'),
#  Text(0.9052186177715091, 0.7045454545454546, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0]'),
#  Text(0.9097320169252469, 0.7045454545454546, 'x[1] <= 0.805\ngini = 0.575\nsamples = 38\nvalue = [0, 0, 7, 22, 9, 0]'),
#  Text(0.9007052186177715, 0.6590909090909091, 'x[2] <= 0.368\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 5, 4, 1, 0]'),
#  Text(0.8984485190409027, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.9029619181946403, 0.6136363636363636, 'x[3] <= 0.295\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 2, 4, 1, 0]'),
#  Text(0.9007052186177715, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9052186177715091, 0.5681818181818182, 'x[0] <= 11.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.9029619181946403, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.907475317348378, 0.5227272727272727, 'x[3] <= 0.37\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.9052186177715091, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9097320169252469, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9187588152327222, 0.6590909090909091, 'x[2] <= 0.4\ngini = 0.5\nsamples = 28\nvalue = [0, 0, 2, 18, 8, 0]'),
#  Text(0.9119887165021157, 0.6136363636363636, 'x[3] <= 0.355\ngini = 0.496\nsamples = 11\nvalue = [0, 0, 0, 5, 6, 0]'),
#  Text(0.9097320169252469, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9142454160789845, 0.5681818181818182, 'x[1] <= 0.825\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 0, 3, 6, 0]'),
#  Text(0.9119887165021157, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.9165021156558533, 0.5227272727272727, 'x[1] <= 0.845\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 3, 3, 0]'),
#  Text(0.9142454160789845, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9187588152327222, 0.4772727272727273, 'x[3] <= 0.475\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.9165021156558533, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.921015514809591, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9255289139633286, 0.6136363636363636, 'x[1] <= 0.85\ngini = 0.388\nsamples = 17\nvalue = [0, 0, 2, 13, 2, 0]'),
#  Text(0.9232722143864598, 0.5681818181818182, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.9277856135401975, 0.5681818181818182, 'x[1] <= 0.865\ngini = 0.593\nsamples = 9\nvalue = [0, 0, 2, 5, 2, 0]'),
#  Text(0.9255289139633286, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9300423131170663, 0.5227272727272727, 'x[3] <= 0.51\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5, 0, 0]'),
#  Text(0.9277856135401975, 0.4772727272727273, 'x[2] <= 0.535\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.9255289139633286, 0.4318181818181818, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.9300423131170663, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9322990126939351, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9751763046544428, 0.7954545454545454, 'x[0] <= 13.8\ngini = 0.586\nsamples = 53\nvalue = [0, 0, 3, 19, 28, 3]'),
#  Text(0.9616361071932299, 0.75, 'x[2] <= 0.593\ngini = 0.532\nsamples = 46\nvalue = [0.0, 0.0, 2.0, 16.0, 27.0, 1.0]'),
#  Text(0.9503526093088858, 0.7045454545454546, 'x[1] <= 0.915\ngini = 0.469\nsamples = 34\nvalue = [0, 0, 2, 9, 23, 0]'),
#  Text(0.9413258110014104, 0.6590909090909091, 'x[2] <= 0.37\ngini = 0.401\nsamples = 28\nvalue = [0, 0, 2, 5, 21, 0]'),
#  Text(0.9368124118476728, 0.6136363636363636, 'x[3] <= 0.355\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 2, 0]'),
#  Text(0.9345557122708039, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9390691114245416, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.945839210155148, 0.6136363636363636, 'x[3] <= 0.76\ngini = 0.302\nsamples = 23\nvalue = [0, 0, 2, 2, 19, 0]'),
#  Text(0.9435825105782792, 0.5681818181818182, 'x[0] <= 11.55\ngini = 0.244\nsamples = 22\nvalue = [0, 0, 1, 2, 19, 0]'),
#  Text(0.9390691114245416, 0.5227272727272727, 'x[2] <= 0.485\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.9368124118476728, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9413258110014104, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.948095909732017, 0.5227272727272727, 'x[1] <= 0.745\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 0, 2, 18, 0]'),
#  Text(0.945839210155148, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9503526093088858, 0.4772727272727273, 'x[2] <= 0.525\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 0, 1, 18, 0]'),
#  Text(0.948095909732017, 0.4318181818181818, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 0, 15, 0]'),
#  Text(0.9526093088857546, 0.4318181818181818, 'x[1] <= 0.845\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.9503526093088858, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.9548660084626234, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.948095909732017, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9593794076163611, 0.6590909090909091, 'x[2] <= 0.547\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 4, 2, 0]'),
#  Text(0.9571227080394923, 0.6136363636363636, 'x[2] <= 0.465\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.9548660084626234, 0.5681818181818182, 'x[1] <= 0.96\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.9526093088857546, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9571227080394923, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9593794076163611, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9616361071932299, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.972919605077574, 0.7045454545454546, 'x[3] <= 0.06\ngini = 0.542\nsamples = 12\nvalue = [0, 0, 0, 7, 4, 1]'),
#  Text(0.9684062059238364, 0.6590909090909091, 'x[0] <= 12.6\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 2, 1]'),
#  Text(0.9661495063469676, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9706629055007052, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9774330042313117, 0.6590909090909091, 'x[2] <= 0.692\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 0, 7, 2, 0]'),
#  Text(0.9751763046544428, 0.6136363636363636, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.9796897038081805, 0.6136363636363636, 'x[1] <= 0.79\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.9774330042313117, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9819464033850493, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9887165021156559, 0.75, 'x[2] <= 0.35\ngini = 0.694\nsamples = 7\nvalue = [0, 0, 1, 3, 1, 2]'),
#  Text(0.9864598025387871, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9909732016925247, 0.7045454545454546, 'x[3] <= 0.345\ngini = 0.72\nsamples = 5\nvalue = [0, 0, 1, 1, 1, 2]'),
#  Text(0.9864598025387871, 0.6590909090909091, 'x[3] <= 0.015\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 2]'),
#  Text(0.9842031029619182, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9887165021156559, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9954866008462624, 0.6590909090909091, 'x[1] <= 0.815\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.9932299012693935, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9977433004231312, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]')]

# %% [markdown]
# Debido a la gran cantidad de informacion y al tamaño del arbol no se puede realizar una lectura de los datos

# %%
predicciones = arbol.predict(X_test)

# %%
predicciones
# Out:
# array([8, 5, 5, 5, 6, 5, 6, 7, 5, 6, 5, 6, 5, 6, 7, 6, 6, 7, 5, 7, 5, 6,
#        6, 5, 6, 5, 5, 5, 5, 7, 6, 7, 5, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 6,
#        5, 4, 6, 5, 6, 6, 5, 4, 6, 5, 7, 6, 5, 7, 6, 5, 5, 6, 5, 6, 7, 7,
#        6, 6, 5, 6, 6, 5, 7, 6, 5, 4, 5, 5, 5, 5, 6, 8, 6, 5, 6, 6, 6, 6,
#        7, 6, 7, 6, 5, 6, 6, 6, 5, 5, 6, 5, 6, 7, 5, 5, 7, 6, 5, 6, 5, 7,
#        5, 7, 6, 4, 5, 6, 7, 7, 4, 7, 7, 4, 5, 6, 5, 5, 5, 5, 6, 7, 6, 5,
#        5, 7, 6, 5, 7, 5, 6, 7, 5, 5, 3, 6, 6, 5, 7, 5, 5, 5, 5, 6, 6, 5,
#        5, 5, 6, 4, 6, 5, 7, 6, 6, 4, 6, 7, 6, 5, 6, 5, 5, 5, 5, 5, 6, 5,
#        5, 5, 5, 5, 5, 6, 6, 6, 5, 5, 6, 6, 6, 5, 5, 6, 5, 5, 5, 5, 7, 6,
#        6, 5, 6, 6, 6, 6, 6, 6, 6, 5, 7, 6, 6, 5, 5, 6, 7, 5, 6, 8, 5, 7,
#        5, 6, 6, 5, 6, 6, 5, 4, 4, 7, 6, 5, 6, 5, 5, 6, 6, 3, 6, 5, 6, 6,
#        6, 6, 5, 6, 7, 5, 5, 6, 6, 5, 5, 5, 7, 6, 4, 7, 5, 7, 5, 7, 6, 5,
#        6, 5, 6, 7, 7, 5, 7, 5, 5, 5, 7, 5, 5, 6, 5, 5, 5, 6, 7, 5, 7, 5,
#        6, 7, 5, 6, 5, 6, 5, 5, 5, 6, 5, 6, 5, 6, 6, 6, 6, 5, 5, 6, 5, 6,
#        6, 5, 6, 6, 6, 5, 4, 7, 6, 5, 7, 7], dtype=int64)

# %%
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['Actual'], colnames=['Predicciones'])
# Out:
# Predicciones  3  4   5   6   7  8
# Actual
# 3             0  0   0   1   0  0
# 4             0  3   2   2   1  0
# 5             2  3  99  32  10  0
# 6             0  5  30  71  16  2
# 7             0  1   1  11  21  1
# 8             0  0   0   6   0  0

# %% [markdown]
# Al evaluar la matriz de confusión se puede indagar en como la diagonal indica los valores que el modelo acertó, sin embargo los valores que se encuentran fuera de la diagonal indican desaciertos del modelo o errores en su clasificación, el valor más notorio es el 30 clasificado como vino de clase 6, perteneciendo en realidad a la clase 5.

# %% [markdown]
# 6)	Evaluar el desempeño del modelo en el conjunto de Test con métricas como precisión, recall, F1-score, etc.

# %%
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.60625

# %% [markdown]
# Este indica la exactitud que posee el modelo en comparación con los valores reales, este es del 0.60 o del 60%, para la clase “Quality” lo que indica que las clases predichas para los vinos tienen una exactitud media baja.

# %%
precision = precision_score(y_test, predicciones, average='weighted')
precision
# Out:
# 0.6199679242886178

# %% [markdown]
# Este indica la precisión que posee el modelo, observando los verdaderos positivos sobre el total de los positivos predichos, este es del 0.61 o del 61% indicando una precisión del 61% en la asignación de la calidad de los Vinos.

# %%
recall = recall_score(y_test, predicciones, average='weighted')
recall
# Out:
# 0.60625

# %% [markdown]
# El Recall indica la sensibilidad de los verdaderos positivos sobre el total de los positivos reales, en este caso es del 0.60 indicando una sensibilidad del 60% o en otras palabras media baja.

# %%
f1 = f1_score(y_test, predicciones, average='weighted')
f1
# Out:
# 0.6105747008656185

# %% [markdown]
# El F1 establece un equilibrio entre la precisión y el Recall indicando que el valor para la clase “Quality” es de 0.61 o del 61%.

# %% [markdown]
# 8)	Interpretar, analizar y documentar los resultados obtenidos.
#
# Después de realizar las diferentes actividades se puede concluir:
#
# •	El número total de registros dentro del Dataset es de 1599, dentro de las cuales el alcohol máximo es de 14.9 y el mínimo es de 8.4.
#
# •	No se encontraron datos faltantes, pero si existían datos atípicos dentro de los sulfatos y la acidez volátil
#
# •	Accuracy: este indica la exactitud que posee el modelo en comparación con los valores reales, este es del 0.60 o del 60%, para la clase “Quality” lo que indica que las clases predichas para los vinos tienen una exactitud media baja.
#
# •	La Precisión: este indica la precisión que posee el modelo, observando los verdaderos positivos sobre el total de los positivos predichos, este es del 0.61 o del 61% indicando una precisión del 61% en la asignación de la calidad de los Vinos.
#
# •	El Recall: indica la sensibilidad de los verdaderos positivos sobre el total de los positivos reales, en este caso es del 0.60 indicando una sensibilidad del 60% o en otras palabras media baja.
#
# •	El F1 Score: establece un equilibrio entre la precisión y el Recall indicando que el valor para la clase “Quality” es de 0.61 o del 61%.
#
# •	En base al histograma se puede concluir que el dataset posee las características de 6 clases de vino, pero esta no está balanceada.
#
# •	En base al diagrama de dispersión se puede concluir que entre menor sea la cantidad de alcohol presente en el Vino, mayor será la densidad que este posea,  pero entre mayor sea la cantidad de alcohol mayor será su calidad.
#
# •	En base al diagrama de dispersión se puede concluir que entre mayor sea la cantidad de alcohol presente en el Vino, mayor será su calidad y su acidez volátil será menor.
#
# •	Después de observar el Boxplot se puede concluir que los altos niveles de alcohol en el Vino presentan niveles bajos de sulfatos, acidez volátil y ácido cítrico, además los sulfatos y la acidez volátil poseen valores atípicos en menor medida.
#
# •	Al observar la correlación entre las variables numéricas se puede indicar que aquellas que tienen un valor entre 0 y 1 poseen una correlación directa, mientras que por otro lado aquellas que indican un valor cercano a -1 poseen una correlación baja o nula, como es el caso del ácido cítrico con la acidez volátil.
#
# •	Al observar la matriz de correlación se puede confirmar como el ácido volátil y el ácido cítrico poseen los valores más bajos de correlación, por otro lado, el ácido cítrico y los sulfatos poseen los niveles más altos de correlación dentro de la matriz.
#
# •	Al evaluar la matriz de confusión se puede indagar en como la diagonal indica los valores que el modelo acertó, sin embargo los valores que se encuentran fuera de la diagonal indican desaciertos del modelo o errores en su clasificación, el valor más notorio es el 30 clasificado como vino de clase 6, perteneciendo en realidad a la clase 5.
